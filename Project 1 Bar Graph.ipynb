# %%
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as st

#Data Files
percent_changes = pd.read_csv (r"C:\Users\kkidw\Documents\Spotify Changes.csv")

# %%
plot_pandas = percent_changes.plot.bar(color='b')
# Set the xlabel and ylabel and title
plt.title("Changes in Users")
plt.xlabel("Total Active Montly Users")
plt.ylabel("Premium Users")
# Out:
# Text(0, 0.5, 'Premium Users')
