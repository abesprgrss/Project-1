# %%
import pandas as pd
import os 
import matplotlib.pyplot as plt
import scipy.stats as st
import scipy.stats as linregress
#File to load
premium_users_data = pd.read_csv (r"C:\Users\kkidw\Documents\Premium Users.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15776/1536247436.py in <module>
#       5 import scipy.stats as linregress
#       6 #File to load
# ----> 7 premium_users_data = pd.read_csv (r"C:\Users\kkidw\Documents\Premium Users.csv")
#       8 premium_users_data.head()
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
labels = ['Premium Users', 'Non-Premium Users']
sizes = [49.7999197, 50.200803]
plot = premium_users_data.plot.pie(y='Total Monthly Users', autopct="%1.1f%%")
plt.title("Premium Users vs Non-Premium Users")
plt.ylabel('Total Premium Users')

plt.show()
